# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
from PIL import Image
# %matplotlib inline

# %%
def plot_images(images, img_dir, suffix):
    """
    show images in a grid.
    """
    coords = itertools.product(range(0, 3), range(0, 3))
    f, axarr = plt.subplots(3, 3, figsize=(16, 16))

    for name in images:
        file = img_dir + name + suffix
        img = Image.open(file)
        img = img.convert('RGB')
        x, y = next(coords)
        axarr[x, y].imshow(np.asarray(img))

# %% [markdown]
# # Samples

# %%
images_dir = "../../skynet-data/data/images/"
labels_dir = "../../skynet-data/data/labels/color/"

# for i in $(ls -alh -S |grep png |head -9 |awk '{print $9}') ;do 
#   echo \"$(echo $i |sed 's/\.png//')\"
# done |tr '\n' ','
images = ["17-65473-43663","17-65438-43528","17-65444-43528",
          "17-65443-43528","17-65475-43661","17-65446-43526",
          "17-65501-43588","17-65475-43658","17-65438-43527"]

# %% [markdown]
# ## Some images

# %%
plot_images(images, images_dir, ".jpg")

# %% [markdown]
# ## Some labels

# %%
plot_images(images, labels_dir, ".png")

# %% [markdown]
# # Extract mask

# %%
img = Image.open(labels_dir + images[-1] + ".png")
img = img.convert('RGB')
plt.figure(figsize = (16, 16))
arr = np.asarray(img)
plt.imshow(arr)

# %% [markdown]
# ### Unique colour counts in this mask

# %%
arr.shape
# Out:
# (256, 256, 3)

# %%
colours, counts = np.unique(np.array([str(x) for x in np.reshape(arr, (256*256, -1))]), return_counts=True)
for x, y in zip(colours, counts):
    print(str(x) + " =\t" + str(y))
# Out:
# [  0 255   0] =	20576
# [0 0 0] =	28859
# [255   0   0] =	16101
